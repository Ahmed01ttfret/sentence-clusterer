# %%
import pandas as pd
from content import SentenceClusterer

# %%
data=pd.read_excel('data.xlsx')
data.head()
# Out:
#                     start                     end  Gender   ID          Age  \
# 0 2023-08-17 14:18:10.073 2023-08-17 14:43:29.093  Female  NaN        45-54
# 1 2023-08-17 15:41:19.181 2023-08-17 15:50:52.080     NaN    A        35-44
# 2 2023-08-17 16:18:05.139 2023-08-17 16:27:25.132     NaN    F        55-64
# 3 2023-08-18 20:10:44.056 2023-08-18 20:49:08.602  Female    B  65 and over
# 4 2023-08-18 20:49:08.660 2023-08-18 20:53:57.654  Female  NaN        45-54
#
#          Educational level   \
# 0       No formal education
# 1                   JHS/JSS
# 2  Secondary education /SSS
# 3                   JHS/JSS
# 4                   JHS/JSS
#
#                    Why do you use harvest rainwater?  \
# 0                              For domestic purposes
# 1                To support me for domestic purposes
# 2                               To support our lives
# 3  because we use a lot  of water so we need alte...
# 4                                        for support
#
# ...

# %%
data.isnull().sum()
# Out:
# start             0
# end               0
# Gender            3
# ID               59
# Age               1
#                  ..
# _status           0
# _submitted_by    65
# __version__       0
# _tags            65
# _index            0
# Length: 111, dtype: int64

# %%
data['Why do you use harvest rainwater?'].isnull().sum()
# Out:
# 3

# %%
ana=SentenceClusterer(data['Why do you use harvest rainwater?'].dropna().tolist())

# %%
final_=ana.summarize_clusters('Why do you use harvest rainwater?')

# %%
final_
# Out:
# {'Harvested rainwater is predominantly used for domestic purposes.': 24,
#  'Harvested rainwater is primarily used for domestic purposes.': 23,
#  'Rainwater is harvested to support essential domestic and agricultural needs.': 6,
#  'People use harvested rainwater to save money and supplement their primary water supply due to high usage.': 13,
#  'To support their domestic needs and daily lives.': 4,
#  'Harvesting rainwater provides an alternative source of water to meet high demand and reduce costs.': 10,
#  'Harvested rainwater is predominantly used for sanitary purposes, especially flushing toilets, as an alternative water source.': 16,
#  'The responses generally say that people harvest rainwater as an affordable alternative to supplement their water supply, particularly for non-potable uses.': 21,
#  'People generally use harvested rainwater for irrigation and to supplement their water needs.': 3,
# ...
